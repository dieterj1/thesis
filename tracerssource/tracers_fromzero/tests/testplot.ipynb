fig.add_trace(go.Scattermapbox(
    mode = "markers+lines",
    lon = [x[0] for x in reports],
    lat = [x[1] for x in reports],
    marker = {'size': 10}))

fig.update_layout(
    mapbox = {
        'style': "open-street-map",
        'center': {'lon': 7.423, 'lat': 43.739},
        'zoom': 14})
fig.show(renderer="browser")

# %%
graph = tr.PyGraph()
graph.yendepth = 1
graph.load_graph_all(
        "/home/toon/Documents/PHD/coding/osrm-docker/data-volume/monaco/monaco-latest.osm.pbf",
    )

# %%
coarse_lonlatts, mapmatch_ids = graph.map_match_trace([(a,b,0+i*200) for i,(a,b) in enumerate(reports)], 20.0)

# %%
mapmatch_ids, len(mapmatch_ids)
# Out:
# ([[],
#   [(2834, 0),
#    (2835, 5),
#    (24186, 11),
#    (24185, 17),
#    (24187, 22),
#    (16210, 28),
#    (16209, 34),
#    (16208, 40),
#    (16207, 45),
#    (11636, 51),
#    (11635, 57),
#    (17432, 62),
#    (17431, 68),
#    (13313, 74),
#    (15892, 80),
#    (15885, 85),
#    (15886, 91),
#    (15887, 97),
#    (15888, 102),
#    (15889, 108),
#    (15890, 114),
#    (13416, 120),
#    (15891, 125),
#    (13441, 131),
#    (13442, 137),
#    (13443, 142),
#    (13444, 148),
#    (13445, 154),
#    (13446, 160),
#    (13447, 165),
#    (13448, 171),
#    (11798, 177),
#    (25088, 182),
#    (24232, 188),
#    (4185, 194),
#    (4186, 200)],
#   [(4186, 200),
#    (14576, 202),
#    (25387, 205),
#    (25386, 208),
#    (14253, 210),
#    (26288, 213),
#    (14581, 216),
#    (14582, 218),
#    (10966, 221),
#    (26289, 224),
#    (26290, 226),
#    (10975, 229),
#    (10290, 232),
#    (22938, 234),
#    (23683, 237),
#    (22934, 240),
#    (22929, 242),
# ...

# %%
fig = go.Figure()
for nodes in mapmatch_ids:
    osmlonlat = [graph.get_node_weight(node[0]) for node in nodes]
    fig.add_trace(go.Scattermapbox(
        mode = "markers+lines",
        lon = [x[1] for x in osmlonlat],
        lat = [x[2] for x in osmlonlat],
        marker = {'size': 10}))
fig.update_layout(
    mapbox = {
        'style': "open-street-map",
        'center': {'lon': 7.423, 'lat': 43.739},
        'zoom': 14})
fig.show(renderer="browser")

# %%
all_paths = graph.reports_all_paths(coarse_lonlatts[:4],20.0,0.01)
print(f"found {len(all_paths)} paths through the reports given by coarse_ids")
# Out:
# found 48216 paths through the reports given by coarse_ids
# Sample count: 30361
# Cartesian product took: 2.575µs

# %%
sample_of_all_paths = [all_paths[i] for i in range(0, len(all_paths), len(all_paths)//amt_smpl)]

# %%
fig = go.Figure()
for path in sample_of_all_paths:
    fig.add_trace(go.Scattermapbox(
        mode = "markers+lines",
        lon = [x[0] for x in path],
        lat = [x[1] for x in path],
        marker = {'size': 10}))
fig.update_layout(
    mapbox = {
        'style': "open-street-map",
        'center': {'lon': 7.423, 'lat': 43.739},
        'zoom': 14})
fig.show(renderer="browser")

# %%
all_feature_seqs = graph.reports_to_features(
    coarse_lonlatts[:4], mapmatch_ids, 20.0, 0.01)
